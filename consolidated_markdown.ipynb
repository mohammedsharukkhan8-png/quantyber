# %%
# ========================
# Week 1 Summary
# ========================

# Topics covered this week:
# Day 1 - Vectors & Matrix Multiplication
# Day 2 - Eigenvalues & Eigenvectors
# Day 3 - Complex Numbers & Probability
# Day 4 - Dot Products & Cross Products

# Full notes maintained in physical notebook.

# %%
# ========================
# Week 2 Summary
# ========================

# Topics covered this week:
# Day 1 - Probability Distributions (Uniform & Normal)
# Day 2 - Conditional Probability & Bayes Theorem
# Day 3 - Classical Cryptography & Caesar Cipher
# Day 4 - RSA Encryption & Decryption
# Bonus - LSB Steganography Project

# Full notes maintained in physical notebook.
