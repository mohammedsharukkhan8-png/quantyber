# %%
# ========================
# Week 3 - Day 2: Digital Signatures
# ========================

# %%
from cryptography.hazmat.primitives import hashes, serialization
from cryptography.hazmat.primitives.asymmetric import rsa, padding
from cryptography.hazmat.backends import default_backend

# Step 1 — Generate key pair
private_key = rsa.generate_private_key(
    public_exponent=65537,
    key_size=2048,
    backend=default_backend()
)
public_key = private_key.public_key()
print("Key pair generated! ✅")
print(f"Key size: 2048 bits")

# Step 2 — Message to sign
message = b"Sharuk's quantum security research - authentic document"
print(f"\nMessage: {message.decode()}")
# Out:
# Key pair generated! ✅
# Key size: 2048 bits
#
# Message: Sharuk's quantum security research - authentic document

# %%
# Step 3 — Sign the message with PRIVATE key
signature = private_key.sign(
    message,
    padding.PSS(
        mgf=padding.MGF1(hashes.SHA256()),
        salt_length=padding.PSS.MAX_LENGTH
    ),
    hashes.SHA256()
)
print(f"Signature generated!")
print(f"Signature (first 30 bytes): {signature[:30].hex()}...")
print(f"Signature length: {len(signature)} bytes")

# Step 4 — Verify with PUBLIC key
try:
    public_key.verify(
        signature,
        message,
        padding.PSS(
            mgf=padding.MGF1(hashes.SHA256()),
            salt_length=padding.PSS.MAX_LENGTH
        ),
        hashes.SHA256()
    )
    print(f"\nSignature verified: AUTHENTIC ✅")
except Exception as e:
    print(f"\nSignature verification FAILED ❌: {e}")

# Step 5 — Try verifying a TAMPERED message
tampered_message = b"Sharuk's quantum security research - TAMPERED document"
try:
    public_key.verify(
        signature,
        tampered_message,
        padding.PSS(
            mgf=padding.MGF1(hashes.SHA256()),
            salt_length=padding.PSS.MAX_LENGTH
        ),
        hashes.SHA256()
    )
    print(f"Tampered message verified: AUTHENTIC ✅")
except Exception as e:
    print(f"Tampered message verified: FAILED ❌ Tampering detected!")
# Out:
# Signature generated!
# Signature (first 30 bytes): 549a497215685e2ef7aa46c7aad8abdf06254d97a55fe954d1608e443938...
# Signature length: 256 bytes
#
# Signature verified: AUTHENTIC ✅
# Tampered message verified: FAILED ❌ Tampering detected!

# %%
import numpy as np

# A complex number: a + bi
c1 = complex(3, 2)       # 3 + 2i
c2 = complex(1, 4)       # 1 + 4i

print("c1 =", c1)
print("c2 =", c2)

# Basic operations
print("\nAddition:", c1 + c2)
print("Multiplication:", c1 * c2)

# Real and imaginary parts
print("\nReal part of c1:", c1.real)
print("Imaginary part of c1:", c1.imag)

# Magnitude (distance from origin on the plane)
print("\nMagnitude of c1:", abs(c1))
# Out:
# c1 = (3+2j)
# c2 = (1+4j)
#
# Addition: (4+6j)
# Multiplication: (-5+14j)
#
# Real part of c1: 3.0
# Imaginary part of c1: 2.0
#
# Magnitude of c1: 3.605551275463989

# %%
import numpy as np
import matplotlib.pyplot as plt

# Uniform distribution — like a fair dice
uniform = np.random.uniform(low=0, high=1, size=1000)

plt.hist(uniform, bins=20, color='steelblue', edgecolor='black')
plt.title("Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Uniform distribution — like a fair dice
uniform = np.random.uniform(low=0, high=1, size=1000)

plt.hist(uniform, bins=20, color='steelblue', edgecolor='black')
plt.title("Uniform Distribution")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
