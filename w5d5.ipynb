# %%
# ========================
# Week 5 Summary
# ========================

# Topics covered this week:
# Day 1 - OWASP Top 10 & SQL Injection attack + defense
# Day 2 - XSS & CSRF attacks + defense
# Day 3 - Nmap vulnerability scanning
#          → Port scan, service detection, OS detection
#          → Network mapping (found phone as DNS server)
#          → Jupyter exposure risk identified & understood
# Day 4 - Python Vulnerability Scanner built
#          → Port scanner with risk rating
#          → HTTP security header analyzer
#          → SQL injection detector
#          → Executive report generator
#          → Pushed as Project #2 to GitHub

# Full notes maintained in physical notebook.
