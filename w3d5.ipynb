# %%
# ========================
# Week 3 Summary
# ========================

# Topics covered this week:
# Day 1 - Hashing & SHA-256 & Password Salting
# Day 2 - Digital Signatures — sign & verify
# Day 3 - PKI & Digital Certificates (live inspection)
# Day 4 - Python Security Tools:
#          → File Integrity Checker
#          → Port Scanner
#          → Secure Message Encryptor (Fernet)

# Full notes maintained in physical notebook.
