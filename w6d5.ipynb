# %%
# ========================
# Week 6 Summary
# ========================

# Topics covered this week:
# Day 1 - Incident Response
#          → NIST 6-phase IR framework
#          → Log analyzer — brute force detection
#          → Real-time SSH monitor with alerting

# Day 2 - Threat Hunting
#          → Persistence mechanism hunting
#          → Network connection analysis
#          → External IP identification
#          → Found Anthropic/Claude in own connections! 😄

# Day 3 - Simple SIEM
#          → Multi-source log collection
#          → Risk scoring system
#          → Security dashboard (7/7 checks passed)

# Day 4 - Live Threat Simulation
#          → Brute force simulation → detected 3 IPs
#          → Data exfiltration → C2 ports flagged
#          → Full APT chain → 110/100 risk score
#          → Automated IR response generation

# Full notes maintained in physical notebook.
